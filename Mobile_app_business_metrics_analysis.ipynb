# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузим-данные-и-подготовим-их-к-анализу" data-toc-modified-id="Загрузим-данные-и-подготовим-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузим данные и подготовим их к анализу</a></span><ul class="toc-item"><li><span><a href="#Заменим-названия-столбцов:-приведем-к-нижнему-регистру-и-коректному-написанию" data-toc-modified-id="Заменим-названия-столбцов:-приведем-к-нижнему-регистру-и-коректному-написанию-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Заменим названия столбцов: приведем к нижнему регистру и коректному написанию</a></span></li><li><span><a href="#Преобразуем-данные-в-нужные-типы" data-toc-modified-id="Преобразуем-данные-в-нужные-типы-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Преобразуем данные в нужные типы</a></span></li><li><span><a href="#Проверим-данные-на-наличе-дубликатов" data-toc-modified-id="Проверим-данные-на-наличе-дубликатов-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверим данные на наличе дубликатов</a></span></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li><li><span><a href="#Зададим-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Зададим-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Зададим функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li><li><span><a href="#Проведем-исследовательский-анализ-данных" data-toc-modified-id="Проведем-исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Проведем исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Создадим-пользовательские-профили.-Определим-минимальную-и-максимальную-даты-привлечения-пользователей." data-toc-modified-id="Создадим-пользовательские-профили.-Определим-минимальную-и-максимальную-даты-привлечения-пользователей.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создадим пользовательские профили. Определим минимальную и максимальную даты привлечения пользователей.</a></span></li><li><span><a href="#Определим-из-каких-стран-приходят-посетители.-Какие-страны-дают-больше-всего-платящих-пользователей." data-toc-modified-id="Определим-из-каких-стран-приходят-посетители.-Какие-страны-дают-больше-всего-платящих-пользователей.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Определим из каких стран приходят посетители. Какие страны дают больше всего платящих пользователей.</a></span></li><li><span><a href="#Определим-какими-устройствами-пользуются-посетители.-С-каких-устройств-чаще-всего-заходят-платящие-пользователи." data-toc-modified-id="Определим-какими-устройствами-пользуются-посетители.-С-каких-устройств-чаще-всего-заходят-платящие-пользователи.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Определим какими устройствами пользуются посетители. С каких устройств чаще всего заходят платящие пользователи.</a></span></li><li><span><a href="#Определим-по-каким-рекламным-каналам-шло-привлечение-пользователей.-Какие-каналы-приносят-больше-всего-платящих-пользователей." data-toc-modified-id="Определим-по-каким-рекламным-каналам-шло-привлечение-пользователей.-Какие-каналы-приносят-больше-всего-платящих-пользователей.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Определим по каким рекламным каналам шло привлечение пользователей. Какие каналы приносят больше всего платящих пользователей.</a></span></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Оценим-расходы-на-маркетинг." data-toc-modified-id="Оценим-расходы-на-маркетинг.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Оценим расходы на маркетинг.</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-общую-сумму-расходов" data-toc-modified-id="Посчитаем-общую-сумму-расходов-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Посчитаем общую сумму расходов</a></span></li><li><span><a href="#Выясним-как-траты-распределены-по-источникам." data-toc-modified-id="Выясним-как-траты-распределены-по-источникам.-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Выясним как траты распределены по источникам.</a></span></li><li><span><a href="#Визуализируем-изменения-метрик-во-времени." data-toc-modified-id="Визуализируем-изменения-метрик-во-времени.-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Визуализируем изменения метрик во времени.</a></span></li></ul></li><li><span><a href="#Определим-сколько-в-среднем-стоило-привлечение-одного-покупателя-из-каждого-источника." data-toc-modified-id="Определим-сколько-в-среднем-стоило-привлечение-одного-покупателя-из-каждого-источника.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Определим сколько в среднем стоило привлечение одного покупателя из каждого источника.</a></span><ul class="toc-item"><li><span><a href="#Рассчитаем-средний-CAC-на-одного-пользователя-для-всего-проекта" data-toc-modified-id="Рассчитаем-средний-CAC-на-одного-пользователя-для-всего-проекта-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Рассчитаем средний CAC на одного пользователя для всего проекта</a></span></li><li><span><a href="#Рассчитаем-средний-CAC-для-каждого-источника-трафика" data-toc-modified-id="Рассчитаем-средний-CAC-для-каждого-источника-трафика-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Рассчитаем средний CAC для каждого источника трафика</a></span></li></ul></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li><li><span><a href="#Оценим-окупаемость-рекламы" data-toc-modified-id="Оценим-окупаемость-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценим окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-общую-окупаемость-рекламы.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-общую-окупаемость-рекламы.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проанализируем общую окупаемость рекламы. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span><ul class="toc-item"><li><span><a href="#Начнем-со-всех-стран-кроме-США" data-toc-modified-id="Начнем-со-всех-стран-кроме-США-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Начнем со всех стран кроме США</a></span></li><li><span><a href="#Перейдем-к-США" data-toc-modified-id="Перейдем-к-США-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Перейдем к США</a></span></li></ul></li><li><span><a href="#Построим-графики-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам." data-toc-modified-id="Построим-графики-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам.-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Построим графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.</a></span><ul class="toc-item"><li><span><a href="#Графики-конверсии-и-удержания-с-разбивкой-по-устройствам" data-toc-modified-id="Графики-конверсии-и-удержания-с-разбивкой-по-устройствам-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Графики конверсии и удержания с разбивкой по устройствам</a></span></li><li><span><a href="#Графики-конверсии-и-удержания-с-разбивкой-по-странам" data-toc-modified-id="Графики-конверсии-и-удержания-с-разбивкой-по-странам-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>Графики конверсии и удержания с разбивкой по странам</a></span></li><li><span><a href="#Графики-конверсии-и-удержания-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Графики-конверсии-и-удержания-с-разбивкой-по-рекламным-каналам-5.5.3"><span class="toc-item-num">5.5.3&nbsp;&nbsp;</span>Графики конверсии и удержания с разбивкой по рекламным каналам</a></span></li></ul></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><span><a href="#Выделим-причины-неэффективности-привлечения-пользователей." data-toc-modified-id="Выделим-причины-неэффективности-привлечения-пользователей.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Выделим причины неэффективности привлечения пользователей.</a></span></li><li><span><a href="#Сформулируем-рекомендации-для-отдела-маркетинга." data-toc-modified-id="Сформулируем-рекомендации-для-отдела-маркетинга.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Сформулируем рекомендации для отдела маркетинга.</a></span><ul class="toc-item"><li><span><a href="#По-рекламным-каналам" data-toc-modified-id="По-рекламным-каналам-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>По рекламным каналам</a></span></li><li><span><a href="#По-странам" data-toc-modified-id="По-странам-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>По странам</a></span></li><li><span><a href="#По-устройствам" data-toc-modified-id="По-устройствам-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>По устройствам</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Анализ бизнес-показателей приложения Procrastinate Pro+

# %% [markdown]
# ***Описание проекта***
#
# Мы проводим анализ от лица маркетингового аналитика развлекательного приложения Procrastinate Pro+. Несколько прошлых месяцев наш бизнес постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Нам нужно разобраться в причинах этой ситуации.
#
# У нас в распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов. Нам предстоит изучить, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отричательно влияют на привлечение пользователей.

# %% [markdown]
# ## Загрузим данные и подготовим их к анализу
# Загрузим данные о визитах, заказах и расходах в переменные.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

visits, orders, costs = (
    pd.read_csv('/datasets/visits_info_short.csv'),  # визиты
    pd.read_csv('/datasets/orders_info_short.csv'),  # заказы
    pd.read_csv('/datasets/costs_info_short.csv'),  # расходы на рекламу
)


#visits.head(), orders.head(), costs.head()

# %% [markdown]
# ### Заменим названия столбцов: приведем к нижнему регистру и коректному написанию

# %%
visits = visits.rename(columns={'User Id': 'user_id', 
                            'Region': 'region', 
                            'Device': 'device',
                            'Channel': 'channel',
                            'Session Start': 'session_start',
                            'Session End': 'session_end'})

orders = orders.rename(columns={'User Id': 'user_id', 
                            'Event Dt': 'event_dt', 
                            'Revenue': 'revenue'})

costs = costs.rename(columns={'Channel': 'channel'})

visits.head()
# Out:
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
orders.head()
# Out:
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
costs.head()
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# ### Преобразуем данные в нужные типы

# %% [markdown]
# Тип данных о времени и датах визитов, заказов и проведения рекламных компаний преобразуем в подходящий (datetime, date)

# %%
# преобразование данных о времени
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# ### Проверим данные на наличе дубликатов

# %%
visits.duplicated().sum(), orders.duplicated().sum(), costs.duplicated().sum()
# Out:
# (0, 0, 0)

# %%
round((visits.isna().mean()*100),2)
# Out:
# user_id          0.0
# region           0.0
# device           0.0
# channel          0.0
# session_start    0.0
# session_end      0.0
# dtype: float64

# %%
round((orders.isna().mean()*100),2)
# Out:
# user_id     0.0
# event_dt    0.0
# revenue     0.0
# dtype: float64

# %%
round((costs.isna().mean()*100),2)
# Out:
# dt         0.0
# channel    0.0
# costs      0.0
# dtype: float64

# %% [markdown]
# Дубликаты не обраружены

# %% [markdown]
# ### Выводы:
# - Загрузили данные о визитах, заказах и расходах на рекламу в соотетствующие переменные visits, orders, costs
# - Заменили названия столбцов: привели к нижнему регистру и коректному написанию
# - Привели тип данных о времени и датах визитов, заказов и проведения рекламных компаний к нужному типу данных
# - Проверили данные на наличие дубликатов, они отсутствуют

# %% [markdown]
# ## Зададим функции для расчета и анализа LTV, ROI, удержания и конверсии

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, events, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# <b>А также функции для визуализации этих метрик — filter_data(), plot_retention(), plot_conversion() и plot_ltv_roi().

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Выводы:
# Для дальнейшего анализа мы задали фунции:
# - функция для создания пользовательских профилей get_profiles()
# - функция для расчёта удержания get_retention()
# - функция для расчёта конверсии get_conversion()
# - функция для расчёта LTV и ROI get_ltv()
# - функция для сглаживания фрейма filter_data()
# - функция для визуализации удержания plot_retention()
# - функция для визуализации конверсии plot_conversion()
# - функция для визуализации LTV и ROI plot_ltv_roi()

# %% [markdown]
# ## Проведем исследовательский анализ данных

# %% [markdown]
# ### Создадим пользовательские профили. Определим минимальную и максимальную даты привлечения пользователей.

# %% [markdown]
# Для получения пользовательских профилей вызовем функцию get_profiles(), передав ей данные о посещениях, покупках и тратах на рекламу

# %%
# получаем профили пользователей
profiles = get_profiles(visits, orders, None, costs)
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Определим минимальную и максимальную даты привлечения пользователей.

# %%
print('Минимальная дата привлечения:', profiles['dt'].min())
print('Максимальная дата привлечения:', profiles['dt'].max())
# Out:
# Минимальная дата привлечения: 2019-05-01
# Максимальная дата привлечения: 2019-10-27

# %% [markdown]
# ### Определим из каких стран приходят посетители. Какие страны дают больше всего платящих пользователей.

# %% [markdown]
# Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
by_countries = profiles.pivot_table(
    index='region', 
    values=['user_id', 'payer'], 
    aggfunc={'user_id':'nunique', 'payer': 'sum'}
)
by_countries['%'] = by_countries['payer']/by_countries['user_id']
by_countries.columns = ['Платящие пользователи', 'Пользователи', '% платящих']
by_countries = by_countries.sort_values(by = ['Платящие пользователи'], ascending = False)
by_countries.style.format({'% платящих': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_8092a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Платящие пользователи</th>        <th class="col_heading level0 col1" >Пользователи</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8092a_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_8092a_row0_col0" class="data row0 col0" >6902</td>
#                         <td id="T_8092a_row0_col1" class="data row0 col1" >100002</td>
#                         <td id="T_8092a_row0_col2" class="data row0 col2" >6.90%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# По таблице мы видим, что наибольшее количество пользователей, в том числе платящих, приходит из США. Процент платящих в США также самый высокий, почти в два раза выше чем в других странах.
# В остальных странах статистика очень схожая по всем параметрам, но гараздо более скромная.
#
# Не смотря на хорошие показатели, статистика по США выглядит аномально высокой на фоне других стран.

# %% [markdown]
# ### Определим какими устройствами пользуются посетители. С каких устройств чаще всего заходят платящие пользователи.

# %% [markdown]
# Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
by_device = profiles.pivot_table(
    index='device', 
    values=['user_id', 'payer'], 
    aggfunc={'user_id':'nunique', 'payer': 'sum'}
)
by_device['%'] = by_device['payer']/by_device['user_id']
by_device.columns = ['Платящие пользователи', 'Пользователи', '% платящих']
by_device = by_device.sort_values(by = ['% платящих'], ascending = False)
by_device.style.format({'% платящих': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_68348_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Платящие пользователи</th>        <th class="col_heading level0 col1" >Пользователи</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68348_level0_row0" class="row_heading level0 row0" >Mac</th>
#                         <td id="T_68348_row0_col0" class="data row0 col0" >1912</td>
#                         <td id="T_68348_row0_col1" class="data row0 col1" >30042</td>
#                         <td id="T_68348_row0_col2" class="data row0 col2" >6.36%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# По таблице устройств можно сделать следующие выводы:
# - Больше приходит пользователей с мобильных устройств.
# - Лучше платят пользователи iPhone и Mac
#
# Но можно сказать, что статистика для устройств достаточно ровная.

# %% [markdown]
# ### Определим по каким рекламным каналам шло привлечение пользователей. Какие каналы приносят больше всего платящих пользователей.

# %%
by_channel = profiles.pivot_table(
    index='channel', 
    values=['user_id', 'payer'], 
    aggfunc={'user_id':'nunique', 'payer': 'sum'}
)
by_channel['%'] = by_channel['payer']/by_channel['user_id']
by_channel.columns = ['Платящие пользователи', 'Пользователи', '% платящих']
by_channel = by_channel.sort_values(by = ['Платящие пользователи'], ascending = False)
by_channel.style.format({'% платящих': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_32859_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Платящие пользователи</th>        <th class="col_heading level0 col1" >Пользователи</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_32859_level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#                         <td id="T_32859_row0_col0" class="data row0 col0" >3557</td>
#                         <td id="T_32859_row0_col1" class="data row0 col1" >29144</td>
#                         <td id="T_32859_row0_col2" class="data row0 col2" >12.20%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# По таблице рекламных каналов видим следующее:
# - Хорошие показатели по количеству платящих пользователей у FaceBoom и TipTop. А также организчески пришло достаточно большое их количество
# - По проценту платящих FaceBoom и TipTop также хорошо себя показывают. Также отличные показатели по проценту у AdNonSense, lambdaMediaAds и RocketSuperAds. У остальных этот параметр значительно ниже

# %% [markdown]
# ### Выводы:
# Проанализировав количество всех и платящих пользователей, а также процент платящих, получили следующее
# - По странам: Не смотря на хорошие показатели, статистика по США выглядит аномально высокой на фоне других стран.
# - По устройствам: Статистика по устройствам достаточно ровная, без явных лидеров или аутсайдеров
# - По рекламным каналам: Показатели для всех каналов очень разные. В лидерах по количеству платящих FaceBoom и TipTop. Хороший процент у тех же FaceBoom и TipTop, а также у AdNonSense, lambdaMediaAds и RocketSuperAds.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Оценим расходы на маркетинг.

# %% [markdown]
# #### Посчитаем общую сумму расходов

# %%
print('Расходы на рекламу:', int(profiles['acquisition_cost'].sum()))
# Out:
# Расходы на рекламу: 105497

# %% [markdown]
# #### Выясним как траты распределены по источникам.

# %% [markdown]
# Составим таблицу

# %%
costs_by_source = (profiles.pivot_table(
    index='channel',
    values='acquisition_cost',
    aggfunc='sum')
                   .rename(columns={'acquisition_cost':'Расходы на рекламу'})
                   .sort_values(by = ['Расходы на рекламу'], ascending = False)
)
costs_by_source['% от всех расходов'] = costs_by_source['Расходы на рекламу']/profiles['acquisition_cost'].sum()
costs_by_source = costs_by_source.style.format({'% от всех расходов': '{:.2%}'})

costs_by_source
# Out:
# <style  type="text/css" >
# </style><table id="T_fe22b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Расходы на рекламу</th>        <th class="col_heading level0 col1" >% от всех расходов</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fe22b_level0_row0" class="row_heading level0 row0" >TipTop</th>
#                         <td id="T_fe22b_row0_col0" class="data row0 col0" >54751.300000</td>
#                         <td id="T_fe22b_row0_col1" class="data row0 col1" >51.90%</td>
#             </tr>
#             <tr>
#                         <th id="T_fe22b_level0_row1" class="row_heading level0 row1" >FaceBoom</th>
#                         <td id="T_fe22b_row1_col0" class="data row1 col0" >32445.600000</td>
# ...

# %% [markdown]
# Как видно из таблицы, основной рекламный бюджет (около 83%) идет на два канала TipTop и FaceBoom

# %% [markdown]
# #### Визуализируем изменения метрик во времени.

# %%
profiles.pivot_table(
    index='dt', 
    columns='channel', 
    values='acquisition_cost', 
    aggfunc='sum'
).plot(grid=True, figsize=(12, 6))

plt.ylabel('Затраты на рекламу')
plt.xlabel('Дата')
plt.title('Затраты на рекламу по каналам и датам')
plt.show()

# %% [markdown]
# На графиках мы также видим:
# - Основные затраты приходятся на два канала - TipTop и FaceBoom.
# - Также заметен рост затрат по этим двум каналам во времени.
# - Остальные каналы показывают стабильные во времени затраты и в разы меньше TipTop и FaceBoom.

# %% [markdown]
# ### Определим сколько в среднем стоило привлечение одного покупателя из каждого источника.

# %% [markdown]
# #### Рассчитаем средний CAC на одного пользователя для всего проекта
# Но исключим из расчета "органический" трафик, он бесплатный.

# %%
print('Средняя стоимость привлечения одного пользователя:', profiles.query('channel != "organic"')['acquisition_cost'].mean())
# Out:
# Средняя стоимость привлечения одного пользователя: 1.1274813239427588

# %% [markdown]
# #### Рассчитаем средний CAC для каждого источника трафика
# Составим таблицу

# %%
(profiles
    .pivot_table(
        index='channel', 
        values=['user_id', 
                'acquisition_cost'],
        aggfunc={'user_id':'nunique', 
                 'acquisition_cost':'mean'}
    )
    .rename(columns={'user_id':'Пользователи', 
                     'acquisition_cost':'Средняя стоимость привлечения пользователя'})
    .sort_values(by = ['Средняя стоимость привлечения пользователя'], ascending = False)     
)
# Out:
#                     Средняя стоимость привлечения пользователя  Пользователи
# channel
# TipTop                                                2.799003         19561
# FaceBoom                                              1.113286         29144
# AdNonSense                                            1.008054          3880
# lambdaMediaAds                                        0.724802          2149
# WahooNetBanner                                        0.602245          8553
# RocketSuperAds                                        0.412095          4448
# OppleCreativeMedia                                    0.250000          8605
# YRabbit                                               0.218975          4312
# MediaTornado                                          0.218717          4364
# LeapBob                                               0.210172          8553
# organic                                               0.000000         56439

# %% [markdown]
# Стоимость пользователя из TipTop очень высокая, почти в 2,5 раза выше средней.
#
# Также в лидерах FaceBoom и AdNonSense

# %% [markdown]
# ### Выводы:
# - Общие расходы на рекламу составляют: 105497
# - Основной рекламный бюджет (около 83%) расходуется на два канала TipTop и FaceBoom
# - Затраты по TipTop и FaceBoom продолжают расти.
# - Затраты в остальных источниках значительно ниже и стабильны во времени
# - Средняя стоимость привлечения одного пользователя: 1,13
# - Стоимость пользователя из TipTop в 2,5 раза выше средней, FaceBoom и AdNonSense на уровне средней, остальные существенно ниже

# %% [markdown]
# ## Оценим окупаемость рекламы

# %% [markdown]
# Используя графики LTV, ROI и CAC, проанализируем окупаемость рекламы.
# <br>Будем считать, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.
# <br>А также исключим из расчета "органический" трафик

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14 # горизонт анализа 

non_organic_users = profiles.query('channel != "organic"')

# %% [markdown]
# ### Проанализируем общую окупаемость рекламы. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    non_organic_users, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать такие выводы:
# - Реклама не окупается. ROI к концу двух недель чуть выше 80%.
# - CAC достаточно быстро растет. Вероятно, дело в увеличении рекламного бюджета.
# - Показатель LTV достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
# - Динамика ROI показывает падение соразмерное росту стоимости привлечения клиентов
#
# Чтобы разобраться в причинах, пройдём по всем доступным характеристикам пользователей — стране, источнику и устройству первого посещения.

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    non_organic_users, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# С разбивкой по устройствам всё тоже стабильно плохо.
# Вот что говорят графики:
# - Реклама не окупается почти на всех устройствах, единственное исключение PC. Но и тут динамика не утишительная.
# - Стоимость привлечения для всех устройств отличается, но стабильно растет.
# - Показатель LTV немного отличается у PC но стабилен для всех устройств.
#
# Все стабильно убыточны. Судя по всему дело не в устройстве

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    non_organic_users, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Разбивка по странам выявила явное отклонение США
# Графики показывают что показатели для всех стран кроме США очень близки, реклама окупается на 4-5 день.
# Тем временем в США:
# - Показатель LTV примерно в два раза выше остальных и стабилен - дело не в пользователях
# - Стоимость привлечения в несколько раз выше других стран. Как следствие - реклама в США не окупается
#
# Вероятно в США используют неоправдано дорогие рекламные каналы

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %% [markdown]
# <b>Проблемы с окупаемостью наблюдаются только в США, поэтому построим графики отдельно для США и для других стран.

# %% [markdown]
# #### Начнем со всех стран кроме США

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    non_organic_users.query('region != "United States"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Не смотря на то что реклама окупается в этих странах, обнаружился убыточный рекламный канал - AdNonSense.
# <br>Вероятно имеет смысл от него отказаться

# %% [markdown]
# #### Перейдем к США

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    non_organic_users.query('region == "United States"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Разбивка по рекламным каналам дает достаточно понятную картину:
# - Неокупаются два рекламных канала: TipTop, FaceBoom
# - Стоимость привлечения из TipTop аномально выбивается
# - Показатель LTV FaceBoom не растет
# - Все остальные каналы показывают стабильный LTV и быстро окупаются в первые же дни

# %% [markdown]
# ### Построим графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.

# %% [markdown]
# #### Графики конверсии и удержания с разбивкой по устройствам

# %%
# смотрим конверсию с разбивкой по устройствам
dimensions = ['device']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим удержание с разбивкой по устройствам
dimensions = ['device']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Серьезного внияния устройства не видно. Немного выбиваются пользователи PC, они похуже конвертируются, но при этом лучше удерживаются. На окупаемости это сказаться не должно.

# %% [markdown]
# #### Графики конверсии и удержания с разбивкой по странам

# %%
# смотрим конверсию с разбивкой по странам
dimensions = ['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим удержание с разбивкой по странам
dimensions = ['region']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Заметна региональная зависимость
# <br>В всех странах кроме США схожие, стабильные показатели конверсии и удержания.
# <br>В США мы видим лучшие показатели конверсии. Но в то же время худшее удержание платящих пользователей, что может сказаться на окупаемости.

# %% [markdown]
# #### Графики конверсии и удержания с разбивкой по рекламным каналам

# %%
# смотрим конверсию с разбивкой по рекламным каналам
dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим удержание с разбивкой по рекламным каналам
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Мы видим различную конверсию для всех каналов
# <br>Но очень схожие показатели удержания, за исключением FaceBoom и AdNonSense. С удержанием которых явно проблемы, что вероятно скажется на окупаемости

# %% [markdown]
# ### Выводы:
# <b>Окупается ли реклама в целом?</b>
# - Реклама в целом не окупается. ROI к концу двух недель чуть выше 80%.
#
# <b>Какие устройства, страны и каналы могут снижать окупаемость рекламы?</b>
# - <b>Дело не в устройстве.</b> Разбивка по устройствам показала, что реклама не окупается почти на всех устройствах, единственное исключение PC. Но и тут динамика не утишительная.
# - <b>Разбивка по странам выявила явное отклонение США.</b> В США стоимость привлечения в несколько раз выше других стран. Также в США мы видим большие проблемы с удержанием
# - <b>Разбивка по каналам выявила, что не окупаются три источника: TipTop, FaceBoom, AdNonSense.</b> Для FaceBoom, AdNonSense обнаружилось очень низкое удержание. Стоимость привлечения пользователей из TipTop аномально выбивается
#
# <b>Чем могут быть вызваны проблемы окупаемости?</b>
# - Проблемы с окупаемостью в США связаны с использованием рекламных каналов TipTop и FaceBoom. TipTop чрезвычайно дорогой и его стоимость ежемесячно растет. А у FaceBoom худшие показатели удержания клиентов.
# - Также нужно обратить внимание на канал AdNonSense. Он также дорогой, имеет плохие показатели удержания и не окупается.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В результате анализа мы выявили, что на общую плохую окупаемость полвлияли три канала привлечения пользователей - TipTop, FaceBoom и AdNonSense.
# Несмотря на то, что все три канала генерировали большое количество трафика и показывали хорошую конверсию, они оказались убыточными:
# - TipTop чрезвычайно высокая стоимость привлечения пользователя
# - FaceBoom худшие показатели удержания клиентов
# - AdNonSense плохие показатели и того и другого
#
# При этом на три эти канала приходится около 87% всего рекламного бюджета.

# %% [markdown]
# Отделу маркетинга следует перераспределить бюджет на существующие и стабильно окупаемые каналы привлечения пользователей. Отказаться от TipTop, FaceBoom и AdNonSense. И заняться поиском новых каналов

# %% [markdown]
# ###  Выделим причины неэффективности привлечения пользователей.

# %% [markdown]
# В результате анализа мы выявили, что на общую плохую окупаемость полвлияли три канала привлечения пользователей - TipTop, FaceBoom и AdNonSense.
# Несмотря на то, что все три канала генерировали большое количество трафика и показывали хорошую конверсию, они оказались убыточными:
# - TipTop чрезвычайно высокая стоимость привлечения пользователя
# - FaceBoom худшие показатели удержания клиентов
# - AdNonSense плохие показатели и того и другого
#
# При этом на три эти канала приходится около 87% всего рекламного бюджета.

# %% [markdown]
# ### Сформулируем рекомендации для отдела маркетинга.

# %% [markdown]
# #### По рекламным каналам

# %% [markdown]
# <b>Рекомендация 1</b> - отказаться от убыточных каналов:
# - TipTop и FaceBoom которые используются в США
# - AdNonSense который используется в европейских странах

# %% [markdown]
# <b>Посмотрим еще раз на окупаемость с разбивкой по каналам исключив убыточные каналы</b>

# %%
#уберем из профайлов эти рекламмные каналы
bad_channels = ['TipTop', 'FaceBoom', 'AdNonSense']
new_profiles = non_organic_users.query('channel not in @bad_channels')

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    new_profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# <b>Рекомендация 2</b> - перераспределить ракламный бюджет на другие каналы.
# <br>Как мы видим практически все каналы показывают окупаемость на второйдень, можно использовать любой из них.
# <br>Исключение OppleCreativeMedia и WahooNetBanner, их приоритет должен быть ниже.

# %% [markdown]
# #### По странам

# %% [markdown]
# <b>Посмотрим еще раз на окупаемость с разбивкой по странам, также исключив убыточные каналы</b>

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    new_profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# <b>Рекомендация 3</b> - при перераспределении бюджета отдать предпочтение США и Великобритании.
# <br> Эти страны показывают лучшие результаты окупаемости

# %% [markdown]
# #### По устройствам

# %% [markdown]
# <b>Также посмотрим еще раз и на окупаемость с разбивкой по устройствам, исключив убыточные каналы</b>

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    new_profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Как мы видим данные для всех устройств очень близкие но Mac и iPhone окупаются день быстрее чем PC и Androin.
# <br>Исходя из этого:
#
# <b>Рекомендация 4</b> - при перераспределении бюджета отдать предпочтение устройствам Mac и iPhone.
